# %%
import pandas as pd
import numpy as np
import os
# Print out a quick overview of the data

exists=os.path.isfile('./DSL-StrongPasswordData.csv')
if exists:
    dataset=pd.read_csv("DSL-StrongPasswordData.csv")
else :
    print("password_dataset not exist");   
    
    
dataset.head()
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0    s002             1    1    0.1491       0.3979       0.2488  0.1069
# 1    s002             1    2    0.1111       0.3451       0.2340  0.0694
# 2    s002             1    3    0.1328       0.2072       0.0744  0.0731
# 3    s002             1    4    0.1291       0.2515       0.1224  0.1059
# 4    s002             1    5    0.1249       0.2317       0.1068  0.0895
#
#    DD.t.i  UD.t.i     H.i    ...        H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0  0.1674  0.0605  0.1169    ...     0.1349  0.1484  0.0135  0.0932  0.3515
# 1  0.1283  0.0589  0.0908    ...     0.1412  0.2558  0.1146  0.1146  0.2642
# 2  0.1291  0.0560  0.0821    ...     0.1621  0.2332  0.0711  0.1172  0.2705
# 3  0.2495  0.1436  0.1040    ...     0.1457  0.1629  0.0172  0.0866  0.2341
# 4  0.1676  0.0781  0.0903    ...     0.1312  0.1582  0.0270  0.0884  0.2517
#
#    UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# ...

# %%
# dataset.subject.unique()

# %%
# pd.unique(dataset[['subject','sessionIndex']].values.ravel('K'))

# %%
# dataset.loc[(dataset['sessionIndex'] == 1) & (dataset['rep'] <=50), 'H.t'].sum()

# %%
# grouped = dataset.groupby('subject').agg({"H.period": [sum, min, max]}) 
# grouped.columns = ["_".join(x) for x in grouped.columns.ravel()]
# grouped

# %%
dataset.groupby('subject').sum(axis=1)
#axis=1 ignore non numeric columns
# Out:
#          sessionIndex    rep  H.period  DD.period.t  UD.period.t      H.t  \
# subject
# s002             1800  10200   42.7831      67.8224      25.0393  34.4989
# s003             1800  10200   62.9173      67.6643       4.7470  53.7184
# s004             1800  10200   41.4982      80.4258      38.9276  41.6436
# s005             1800  10200   32.7851     111.2962      78.5111  46.7806
# s007             1800  10200   38.0844      70.5853      32.5009  29.9561
# s008             1800  10200   35.1618      82.9729      47.8111  33.4068
# s010             1800  10200   35.6136      59.6319      24.0183  26.8542
# s011             1800  10200   32.5709      66.2657      33.6948  47.3196
# s012             1800  10200   56.0999      74.2501      18.1502  49.9553
# s013             1800  10200   32.1353      51.5611      19.4258  28.6537
# s015             1800  10200   31.2489      67.2110      35.9621  30.1950
# ...

# %%
dataset.drop(dataset.columns[[1,2]], axis=1, inplace=True)
grouped = dataset.groupby('subject').agg({"max","min","sum"},axis="columns") 
grouped.columns = ["".join(x) for x in grouped.columns.ravel()]
grouped
# Out:
#          H.periodsum  H.periodmin  H.periodmax  DD.period.tsum  \
# subject
# s002         42.7831       0.0103       0.2093         67.8224
# s003         62.9173       0.0372       0.3761         67.6643
# s004         41.4982       0.0420       0.1425         80.4258
# s005         32.7851       0.0415       0.1412        111.2962
# s007         38.0844       0.0478       0.1370         70.5853
# s008         35.1618       0.0069       0.1602         82.9729
# s010         35.6136       0.0449       0.1212         59.6319
# s011         32.5709       0.0372       0.1578         66.2657
# s012         56.0999       0.0014       0.2974         74.2501
# s013         32.1353       0.0465       0.1154         51.5611
# s015         31.2489       0.0246       0.1452         67.2110
# s016         41.7122       0.0602       0.1716        174.1457
# s017         28.5121       0.0444       0.0971         74.7273
# s018         36.6515       0.0436       0.1655         64.5126
# ...

# %%
grouped = dataset.groupby('subject').agg("sum",axis="columns") 
grouped.columns = ["".join(x) for x in grouped.columns.ravel()]
grouped
# Out:
#          H.period  DD.period.t  UD.period.t      H.t    DD.t.i    UD.t.i  \
# subject
# s002      42.7831      67.8224      25.0393  34.4989   60.0774   25.5785
# s003      62.9173      67.6643       4.7470  53.7184   62.2208    8.5024
# s004      41.4982      80.4258      38.9276  41.6436   59.2570   17.6134
# s005      32.7851     111.2962      78.5111  46.7806   90.9143   44.1337
# s007      38.0844      70.5853      32.5009  29.9561   48.2675   18.3114
# s008      35.1618      82.9729      47.8111  33.4068   45.9798   12.5730
# s010      35.6136      59.6319      24.0183  26.8542   58.9046   32.0504
# s011      32.5709      66.2657      33.6948  47.3196   56.1902    8.8706
# s012      56.0999      74.2501      18.1502  49.9553   59.6739    9.7186
# s013      32.1353      51.5611      19.4258  28.6537   46.5642   17.9105
# s015      31.2489      67.2110      35.9621  30.1950   41.7232   11.5282
# s016      41.7122     174.1457     132.4335  26.7414   98.0073   71.2659
# ...

# %%
[s.split('.')[0] for s in grouped.T.index.values]
grouped.T.groupby([s.split('.')[0] for s in grouped.T.index.values]).sum().T
# Out:
#                 DD         H         UD
# subject
# s002      943.4850  413.7851   562.7799
# s003      796.1431  555.0985   280.7282
# s004      850.4708  441.4984   439.1841
# s005     1169.6540  453.9061   752.5841
# s007      684.2685  402.5740   315.2474
# s008      708.7603  411.2176   337.7912
# s010      681.8106  325.5837   387.5789
# s011      665.2609  489.6038   225.8527
# s012      837.5457  592.5896   301.0516
# s013      643.1589  344.3046   332.9532
# s015      713.8846  332.6035   410.2391
# s016     1659.6212  416.2342  1280.8144
# s017      729.8234  267.3475   487.1461
# s018      843.8545  435.7527   439.0402
# s019     1133.9708  366.8901   805.1170
# s020      867.1916  472.4400   435.8408
# s021      886.7623  370.8195   549.6032
# s022     1823.8181  262.3762  1583.9268
# s024     1070.8002  263.3423   835.0839
# s025     1105.2284  355.7353   784.6052
# s026      850.8433  377.3825   511.1207
# s027     1030.8728  438.4568   624.4921
# ...
